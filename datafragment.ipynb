# %%
#  importo las librerias
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Lista de datos con el se trabajo en el algoritmo
calificaciones = [
{"nombre": "Juan", "matematicas": 85, "ciencias": 90,
"historia": 75},
{"nombre": "María", "matematicas": 70, "ciencias": 80,
"historia": 85},
{"nombre": "Pedro", "matematicas": 95, "ciencias": 75,
"historia": 90},
{"nombre": "Ana", "matematicas": 80, "ciencias": 85, "historia":
80},
{"nombre": "Luis", "matematicas": 75, "ciencias": 70,
"historia": 95},
{"nombre": "Sofía", "matematicas": 90, "ciencias": 85,
"historia": 75},
{"nombre": "Carlos", "matematicas": 85, "ciencias": 90,
"historia": 80},
{"nombre": "Elena", "matematicas": 70, "ciencias": 75,
"historia": 85},
{"nombre": "Javier", "matematicas": 80, "ciencias": 85,
"historia": 90},
{"nombre": "Laura", "matematicas": 75, "ciencias": 70,
"historia": 95},
{"nombre": "Diego", "matematicas": 90, "ciencias": 85,
"historia": 75},
{"nombre": "Paula", "matematicas": 85, "ciencias": 90,
"historia": 80},
{"nombre": "Carmen", "matematicas": 70, "ciencias": 75,
"historia": 85}
]

# %%
# Defino todas las varibles
all_matematica=[]
all_ciencias=[]
all_historia=[]
nota_maxima=13*100
aprobados_matematica=0
may_ciencias=0
may_historia=0
may_matematica=0
aprobados_matematica=[]
aprobados_ciencias=[]
aprobados_historia=[]
fi_mate=[]
fi_ciencias=[]
fi_historia=[]

# %%
# Hago un for a los datos de ls calificaciones
for i in calificaciones:
    # Todas las notas de matematicas los agrego a un array 
    nota_matematica=i["matematicas"]
    all_matematica.append(nota_matematica)
    # Todas las notas de ciencias los agrego a un array 
    nota_ciencias=i["ciencias"]
    all_ciencias.append(nota_ciencias)
    # Todas las notas de Historia los agrego a un array 
    nota_historia=i["historia"]
    all_historia.append(nota_historia)

# Recorro el array de todas las notas de matematica
    for nota_mat in range(len(all_matematica)):
# Busca la nota mas alta en matematica
            if all_matematica[nota_mat] > may_matematica:
# Agrego a la variable la nota mas alta en matematica
                may_matematica = all_matematica[nota_mat]
# Busco el alumno que concida con la nota de matematica
    if may_matematica==i["matematicas"]:
# Agrego a la variable el alumno que concida con la nota de matematica y guarda toda la informacion de ese alumno
          alumno_matematica=i

# Recorro el array de todas las notas de ciencias
    for nota_ciencia in range(len(all_ciencias)):
    # Busca la nota mas alta en ciencias
            if all_ciencias[nota_ciencia ] > may_ciencias:
    # Agrego a la variable la nota mas alta en ciencias
                may_ciencias = all_ciencias[nota_ciencia ]

# Busco el alumno que concida con la nota de ciencias
    if may_ciencias==i["ciencias"]:
# Agrego a la variable el alumno que concida con la nota de ciencias y guarda toda la informacion de ese alumno
          alumno_ciencias=i

# Recorro el array de todas las notas de historia
    for nota_historia in range(len(all_historia)):
    # Busca la nota mas alta en historia
            if all_historia[nota_historia] > may_historia:
    # Agrego a la variable la nota mas alta en historia
                may_historia = all_historia[nota_historia]
# Busco el alumno que concida con la nota de historia
    if may_historia==i["historia"]:
# Agrego a la variable el alumno que concida con la nota de historia y guarda toda la informacion de ese alumno
          alumno_historia=i
  
for nota_60_mat in all_matematica:
            if nota_60_mat >= 60:
                aprobados_matematica.append(nota_60_mat)

for nota_60_cien in all_ciencias:
    if nota_60_cien >= 60:
        aprobados_ciencias.append(nota_60_cien)
    
for nota_60_his in all_historia:
    if nota_60_his >= 60:
        aprobados_historia.append(nota_60_his)

# %%
print("aprobaron matematica: ", len(aprobados_matematica))
print("aprobaron ciencias: ", len(aprobados_ciencias))
print("aprobararon historia: ", len(aprobados_historia))

print("nota mas alta en matematica: ", alumno_matematica["nombre"], alumno_matematica["matematicas"])
print("nota mas alta en ciencias: ", alumno_ciencias["nombre"], alumno_ciencias["ciencias"])
print("nota mas alta en historia: ", alumno_historia["nombre"], alumno_ciencias["historia"])

print("may_matematica: ", aprobados_matematica)
print("may_ciencias: ", may_ciencias)
print("may_historia: ", may_historia)

# %%
# 
avg_mat=sum(all_matematica) / nota_maxima * 100
avg_ciencia=sum(all_ciencias) / nota_maxima * 100
avg_historia= sum(all_historia) / nota_maxima * 100

#Imrpimo el promedio de los alumnos de las tres materia: matematica, ciencia y historia
print("promedio de los alumnos en matematica", avg_mat )
print("promedio de los alumnos en ciencias", avg_ciencia)
print("promedio de los alumnos en historia", avg_historia)
